# %% [markdown]
# # 4.7 Deriving New Variables

# %% [markdown]
# ### This script contains the following points
#
# #### 1. Import libraries
# #### 2. Import data
# #### 3. User defined functions
# #### 4. If Statements with the loc() function
# #### 5. If Statements with For-loops
# #### 6. Task 4.7
# #### 7. Export the data

# %% [markdown]
# # 01. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Import ords_prods_merged
path = r'L:\CareerFoundary\Immersion into Data Analystics\4 Python Fundamentals for Data Analysts\Instacart Basket Analysis'

# %%
path
# Out:
# 'L:\\CareerFoundary\\Immersion into Data Analystics\\4 Python Fundamentals for Data Analysts\\Instacart Basket Analysis'

# %%
df_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_merged.head()
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                    15.0         False         196                  1
# 2                    21.0         False         196                  1
# 3                    29.0         False         196                  1
# 4                    28.0         False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices _merge
# ...

# %%
# Create subset
df_opm = df_merged[:1000000]

# %%
df_opm.shape
# Out:
# (1000000, 15)

# %% [markdown]
# # 03. User Defined Functions

# %%
# Define a function
def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid range product'
    elif row['prices'] > 15:
        return 'High range product'
    else: return np.nan

# %%
# Apply the function
df_opm['price_range'] = df_opm.apply(price_label, axis =1)
# Out:
# C:\Users\Kristina\AppData\Local\Temp\ipykernel_16280\1165407820.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opm['price_range'] = df_opm.apply(price_label, axis =1)

# %%
df_opm['price_range'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range, dtype: int64

# %%
df_opm['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # 04 If-statements with the loc() Function

# %%
#create conditions
df_opm.loc[df_opm['prices'] > 15, 'price_range_loc'] = 'High range product'
# Out:
# C:\Users\Kristina\AppData\Local\Temp\ipykernel_16280\3943663875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_opm.loc[df_opm['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df_opm.loc[(df_opm['prices'] <= 15) & (df_opm['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df_opm.loc[df_opm['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df_opm['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range_loc, dtype: int64

# %%
# try code with entire dataframe
df_merged.loc[df_merged['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df_merged.loc[(df_merged['prices'] <= 15) & (df_merged['prices'] > 5), 'price_range_loc'] = 'Mid range product'

# %%
df_merged.loc[df_merged['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# # 05 If-statements with For-Loops

# %%
# finding frequency of orders_day_of_the_week
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 16 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   customer_id             int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   new_customer            bool
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  _merge                  category
#  15  price_range_loc         object
# dtypes: bool(1), category(1), float64(2), int64(10), object(2)
# memory usage: 3.7+ GB

# %%
df_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
# define 'busiest day'
result = []

for value in df_merged['orders_day_of_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_merged['busiest_day'] = result

# %%
df_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # 06 Task 4.7

# %% [markdown]
# ## Q1. If you haven’t done so already, complete the instructions in the Exercise for creating the “price_label” and “busiest_day” columns.

# %% [markdown]
# ## Q2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# finding current column names
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   customer_id             int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   new_customer            bool
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  _merge                  category
#  15  price_range_loc         object
#  16  busiest_day             object
# dtypes: bool(1), category(1), float64(2), int64(10), object(3)
# memory usage: 3.9+ GB

# %%
# wondering why I have two busiest day
df_merged.head(10)
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
# 5   3367565            1             6                   2                  7
# 6    550135            1             7                   1                  9
# 7   3108588            1             8                   1                 14
# 8   2295261            1             9                   1                 16
# 9   2550362            1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# ...

# %%
# checking output
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   customer_id             int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   new_customer            bool
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  _merge                  category
#  15  price_range_loc         object
#  16  busiest_day             object
# dtypes: bool(1), category(1), float64(2), int64(10), object(3)
# memory usage: 3.9+ GB

# %%
# renaming 'busiest day' column
df_merged.rename(columns = {'busiest_day' : 'Busiest Days'}, inplace = True)

# %%
# checking output
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 17 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   customer_id             int64
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
#  6   new_customer            bool
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  product_name            object
#  11  aisle_id                int64
#  12  department_id           int64
#  13  prices                  float64
#  14  _merge                  category
#  15  price_range_loc         object
#  16  Busiest Days            object
# dtypes: bool(1), category(1), float64(2), int64(10), object(3)
# memory usage: 3.9+ GB

# %%
# define 'Busiest days'
result = []

for value in df_merged['orders_day_of_week']:
    if value == 1 or value == 0:
        result.append('Busiest days')
    elif value == 4 or value == 3:
        result.append('Slowest days')
    else:
        result.append('Regular days')

# %%
df_merged['Busiest Days'] = result

# %%
# checking output
df_merged.head(10)
# Out:
#    order_id  customer_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329            1             1                   2                  8
# 1   2398795            1             2                   3                  7
# 2    473747            1             3                   3                 12
# 3   2254736            1             4                   4                  7
# 4    431534            1             5                   4                 15
# 5   3367565            1             6                   2                  7
# 6    550135            1             7                   1                  9
# 7   3108588            1             8                   1                 14
# 8   2295261            1             9                   1                 16
# 9   2550362            1            10                   4                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# ...

# %% [markdown]
# ## Q3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
df_merged['Busiest Days'].value_counts(dropna = False)
# Out:
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: Busiest Days, dtype: int64

# %% [markdown]
# ## Q4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.

# %%
# determine busiest period
df_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
# define 'most orders'
result = []

for value in df_merged['order_hour_of_day']:
    if value == 11 or value == 10:
        result.append('Most orders')
    elif value == 4 or value == 3:
        result.append('Fewest orders')
    else:
        result.append('Average orders')

# %%
#checking output
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
# creating new columns
df_merged['busiest_period_of_day'] = result

# %% [markdown]
# ## Q5. Print the frequency for this new column

# %%
# checking for errors
df_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Average orders    26802436
# Most orders        5497900
# Fewest orders       104523
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# # 07 Exporting data

# %%
#exporting data
df_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'merge_busy_orders.pkl'))
